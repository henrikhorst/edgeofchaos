# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
r_df=pd.read_csv('R_values_fireflies100_180s_3fold.csv',index_col=0)

# %%
r_df.iloc[:,:11]
# Out:
#                                       1                        1k  \
# $Δ$t: 100.0ms              (1, 0, 0, 0)              (2, 0, 0, 0)
# $Δ$t: 64.0ms               (4, 0, 0, 0)              (0, 0, 0, 0)
# $Δ$t: 32.0ms              (1, -1, 0, 0)              (0, 0, 0, 0)
# $Δ$t: 16.0ms               (1, 0, 0, 0)             (0, -1, 0, 0)
# $Δ$t: 8.0ms                (1, 0, 0, 0)          (-1, -2, -2, -2)
# $Δ$t: 4.0ms             (0, -1, -1, -1)             (1, 0, -1, 0)
# $Δ$t: 2.0ms               (0, 0, -1, 0)           (0, -4, -4, -4)
# $Δ$t: 1.0ms                (0, 0, 0, 0)           (0, -3, -3, -3)
# $Δ$t: 0.1ms             (0, -8, -8, -8)          (-3, -2, -2, -2)
# $Δ$t: 0.01ms       (-10, -10, -10, -10)          (-9, -9, -9, -9)
# $Δ$t: 0.001ms  (-138, -139, -139, -139)  (-138, -139, -139, -139)
#
#                                    2500                        5k  \
# $Δ$t: 100.0ms              (0, 0, 0, 0)              (4, 4, 0, 3)
# ...

# %%
x=[]
for elem in r_df.iloc[6,:]:
    x.append(elem[1])
print(x)    
plt.plot(x)
# Out:
# ['0', '0', '6', '-', '-', '-', '-', '-', '-', '-', '-']

# %%
r_df.iloc[:,11:]
# Out:
# Empty DataFrame
# Columns: []
# Index: [$Δ$t: 100.0ms, $Δ$t: 64.0ms, $Δ$t: 32.0ms, $Δ$t: 16.0ms, $Δ$t: 8.0ms, $Δ$t: 4.0ms, $Δ$t: 2.0ms, $Δ$t: 1.0ms, $Δ$t: 0.1ms, $Δ$t: 0.01ms, $Δ$t: 0.001ms]
